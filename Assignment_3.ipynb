# %%
#Question No 1...
value1 = int(input("Enter value 1: \t"))
operator = input("/nEnter any operator '+' , '-', '*', '/', '**' : \t")
value2 = int(input("/nEnter value 2: \t"))


if operator == '+':
    plus = value1 + value2
    print("\nValue1 + Value2 = ",plus)

elif operator == '-':
    minus = value1 - value2
    print("\nValue1 - Value2 = ",minus)

elif operator == '*':
    multiply = value1 * value2
    print("\nValue1 * Value2 = ",multiply)

elif operator == '/':
    divide = value1 + value2
    print("\nValue1 / Value2 = ",divide)
    
elif operator == '**':
    power = value1**value2
    print("\nValue1 ** Value2 = ",power)

else:
    print("\nEnter Correct Operator...! ")



#Question No 2...
test_list = [ 1,2, 6, 3, 5, 3, 4,"a","b","c"]
print("\n\nChecking if any Numeric exists in list ( using loop ) : ") 

for i in test_list: 
  
    if(2 in test_list): 
        print ("Numeric Exists...")
        break
    elif("b" in test_list):
        print("String Exists...")
        break

        

#Question No 3...
myData = {
    "firstname": "Fahad",
    "lastname" : "Maqsood",
    "Address"  : "Pakistan Sindh Hyderabad"
}
print("\n\nBefore Add a Key: " ,myData)
myData["Phone"] = 12345
print("\nAfter Add a Key in Dictionary : ",myData)



#Question No 4...
myDict = {
    'a' : 100, 
    'b' : 200, 
    'c' : 300, 
    'd' : 400
} 
s = 0
for i in myDict: 
        s = s + myDict[i] 
print("\n\n\nSum of All the Numeric Values :",(s)) 
print("\n\n\n")




#Question No 5...    
lst = [ 3, 6, 9, 12, 3, 30, 15, 9, 45, 36, 12, 12]
dupItems = []
uniqItems = {}
for x in lst:
    if x not in uniqItems:
        uniqItems[x] = 1
    else:
        if uniqItems[x] == 1:
            dupItems.append(x)
            uniqItems[x] += 1
            print("Duplicate Items Are: ",dupItems)

            
            
            
##Question No 6...
check_dictionary = input("\n\n\nEnter Any Alphabet Key..!\t")
mydictionary = {
    "a" : 1,
    "b" : 2,
    "c" : 3,
    "d" : 4
}
if check_dictionary in mydictionary.keys():
    print("\nThe Input Key is Already Exist in the Dictionary...!")
else:
    print("The Key in Not in the List...!")
    print("Please.. Enter the Alphabet Key First..!")
# Out:
# Enter value 1: 	20
# /nEnter any operator '+' , '-', '*', '/', '**' : 	*
# /nEnter value 2: 	5
#
# Value1 * Value2 =  100
#
#
# Checking if any Numeric exists in list ( using loop ) :
# Numeric Exists...
#
#
# Before Add a Key:  {'firstname': 'Fahad', 'lastname': 'Maqsood', 'Address': 'Pakistan Sindh Hyderabad'}
#
# After Add a Key in Dictionary :  {'firstname': 'Fahad', 'lastname': 'Maqsood', 'Address': 'Pakistan Sindh Hyderabad', 'Phone': 12345}
#
#
#
# Sum of All the Numeric Values : 1000
#
#
#
#
# Duplicate Items Are:  [3]
# Duplicate Items Are:  [3, 9]
# Duplicate Items Are:  [3, 9, 12]
#
#
#
# Enter Any Alphabet Key..!	c
#
# The Input Key is Already Exist in the Dictionary...!
